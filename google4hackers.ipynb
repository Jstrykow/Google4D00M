# %% [markdown]
# <a href="https://colab.research.google.com/github/Jstrykow/Google4D00M/blob/main/google4hackers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/drive/1gZM4pAfH4kroa_44gNYZEE8RDVMiO9cP#scrollTo=pACRk2JWWGu3
# https://github.com/nicknochnack/DoomReinforcementLearning/blob/main/VizDoom-Basic-Tutorial.ipynb

# %%
# %%bash
# # Install deps from
# # https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md#-linux
#
# apt-get update
#
# apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev \
# nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev \
# libopenal-dev timidity libwildmidi-dev unzip
#
# # Boost libraries
# apt-get install libboost-all-dev
#
# # Lua binding dependencies
# apt-get install liblua5.1-dev
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:6 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Ign:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,326 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,160 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,602 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,449 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,380 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,594 kB]
# Fetched 18.8 MB in 9s (2,199 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# build-essential is already the newest version (12.9ubuntu3).
# libbz2-dev is already the newest version (1.0.8-5build1).
# libbz2-dev set to manually installed.
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# unzip is already the newest version (6.0-26ubuntu3.2).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu9.2).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   autopoint debhelper debugedit dh-autoreconf dh-strip-nondeterminism dwz fluid-soundfont-gm
#   freepats gettext gettext-base gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0
#   gir1.2-gtk-2.0 gir1.2-harfbuzz-0.0 gir1.2-ibus-1.0 gir1.2-pango-1.0 intltool-debian libao-common
#   libao4 libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev libblkid-dev libblkid1
#   libcairo-script-interpreter2 libcairo2-dev libdatrie-dev libdbus-1-dev libdebhelper-perl
#   libdecor-0-dev libdrm-dev libegl-dev libegl1-mesa-dev libffi-dev libfile-stripnondeterminism-perl
#   libfluidsynth3 libfribidi-dev libgail-common libgail18 libgbm-dev libgdk-pixbuf-2.0-dev
#   libgdk-pixbuf2.0-bin libgl-dev libgles-dev libgles1 libglib2.0-dev libglib2.0-dev-bin
#   libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev libgraphite2-dev
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0
#   libibus-1.0-5 libibus-1.0-dev libice-dev libinstpatch-1.0-2 libinstpatch-dev liblzo2-2
#   libmail-sendmail-perl libmount-dev libmount1 libopengl-dev libpango1.0-dev libpangoxft-1.0-0
#   libpciaccess-dev libpixman-1-dev libpulse-dev libpulse-mainloop-glib0 librsvg2-common
#   libselinux1-dev libsepol-dev libsm-dev libsndio-dev libsub-override-perl
#   libsys-hostname-long-perl libsystemd-dev libthai-dev libtool libudev-dev libudev1 libwayland-bin
#   libwayland-dev libwildmidi-config libwildmidi2 libxcb-render0-dev libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxdamage-dev libxfixes-dev libxi-dev libxinerama-dev
#   libxkbcommon-dev libxml2-utils libxrandr-dev libxt-dev libxv-dev libxxf86vm-dev pango1.0-tools
#   po-debconf
# Suggested packages:
#   dh-make fluid-soundfont-gs gettext-doc libasprintf-dev libgettextpo-dev libaudio2 libsndio6.1
#   libcairo2-doc libdatrie-doc libgirepository1.0-dev libglib2.0-doc libgraphite2-utils gvfs
#   libgtk2.0-doc libice-doc cryptsetup-bin libpango1.0-doc libsm-doc libthai-doc libtool-doc gcj-jdk
#   libwayland-doc libxt-doc graphicsmagick libmail-box-perl ncompress tar-scripts tar-doc pmidi
#   timidity-daemon
# The following NEW packages will be installed:
#   autopoint debhelper debugedit dh-autoreconf dh-strip-nondeterminism dwz fluid-soundfont-gm
#   freepats gettext gettext-base gir1.2-atk-1.0 gir1.2-freedesktop gir1.2-gdkpixbuf-2.0
#   gir1.2-gtk-2.0 gir1.2-harfbuzz-0.0 gir1.2-ibus-1.0 gir1.2-pango-1.0 intltool-debian libao-common
#   libao4 libarchive-cpio-perl libarchive-zip-perl libatk1.0-dev libblkid-dev
#   libcairo-script-interpreter2 libcairo2-dev libdatrie-dev libdbus-1-dev libdebhelper-perl
#   libdecor-0-dev libdrm-dev libegl-dev libegl1-mesa-dev libffi-dev libfile-stripnondeterminism-perl
#   libfluidsynth-dev libfluidsynth3 libfribidi-dev libgail-common libgail18 libgbm-dev
#   libgdk-pixbuf-2.0-dev libgdk-pixbuf2.0-bin libgl-dev libgles-dev libgles1 libglib2.0-dev
#   libglib2.0-dev-bin libglu1-mesa libglu1-mesa-dev libglvnd-core-dev libglvnd-dev libglx-dev
#   libgme-dev libgraphite2-dev libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libgtk2.0-dev
#   libharfbuzz-dev libharfbuzz-gobject0 libharfbuzz-icu0 libibus-1.0-5 libibus-1.0-dev libice-dev
#   libinstpatch-1.0-2 libinstpatch-dev liblzo2-2 libmail-sendmail-perl libmount-dev libopenal-dev
#   libopengl-dev libpango1.0-dev libpangoxft-1.0-0 libpciaccess-dev libpixman-1-dev libpulse-dev
#   libpulse-mainloop-glib0 librsvg2-common libsdl2-dev libselinux1-dev libsepol-dev libsm-dev
#   libsndio-dev libsub-override-perl libsys-hostname-long-perl libsystemd-dev libthai-dev libtool
#   libudev-dev libwayland-bin libwayland-dev libwildmidi-config libwildmidi-dev libwildmidi2
#   libxcb-render0-dev libxcb-shm0-dev libxcomposite-dev libxcursor-dev libxdamage-dev libxfixes-dev
#   libxi-dev libxinerama-dev libxkbcommon-dev libxml2-utils libxrandr-dev libxt-dev libxv-dev
#   libxxf86vm-dev nasm pango1.0-tools po-debconf timidity
# The following packages will be upgraded:
#   libblkid1 libmount1 libudev1 tar
# 4 upgraded, 113 newly installed, 0 to remove and 47 not upgraded.
# Need to get 176 MB of archives.
# After this operation, 272 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 tar amd64 1.34+dfsg-1ubuntu0.1.22.04.2 [295 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libblkid1 amd64 2.37.2-4ubuntu3.4 [103 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmount1 amd64 2.37.2-4ubuntu3.4 [122 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev1 amd64 249.11-0ubuntu3.12 [78.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 autopoint all 0.21-4ubuntu4 [422 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdebhelper-perl all 13.6ubuntu1 [67.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtool all 2.4.6-15build2 [164 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 dh-autoreconf all 20 [16.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libarchive-zip-perl all 1.68-1 [90.2 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-override-perl all 0.09-2 [9,532 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-stripnondeterminism-perl all 1.13.0-1 [18.1 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 dh-strip-nondeterminism all 1.13.0-1 [5,344 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 debugedit amd64 1:5.0-4build1 [47.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 dwz amd64 0.14-1build2 [105 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 intltool-debian all 0.35.0+20060710.5 [24.9 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 po-debconf all 1.0.21+nmu1 [233 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 debhelper all 13.6ubuntu1 [923 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluid-soundfont-gm all 3.1-5.3 [130 MB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freepats all 20060219-4 [27.9 MB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-atk-1.0 amd64 2.36.0-3build1 [21.0 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-freedesktop amd64 1.72.0-1 [22.3 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.42.8+dfsg-1ubuntu0.3 [9,486 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-common all 2.24.33-2ubuntu2.1 [125 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-harfbuzz-0.0 amd64 2.7.4-1ubuntu3.1 [31.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoxft-1.0-0 amd64 1.50.6+ds-2ubuntu1 [31.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-pango-1.0 amd64 1.50.6+ds-2ubuntu1 [44.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-0 amd64 2.24.33-2ubuntu2.1 [2,038 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gir1.2-gtk-2.0 amd64 2.24.33-2ubuntu2.1 [210 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-5 amd64 1.5.26-4 [183 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 gir1.2-ibus-1.0 amd64 1.5.26-4 [88.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libao-common all 1.2.2+20180113-1.1ubuntu3 [6,568 B]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libao4 amd64 1.2.2+20180113-1.1ubuntu3 [35.2 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libarchive-cpio-perl all 0.10-1.1 [9,928 B]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libffi-dev amd64 3.4.2-4 [63.7 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.3 [117 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libblkid-dev amd64 2.37.2-4ubuntu3.4 [185 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsepol-dev amd64 3.3-1build1 [378 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libselinux1-dev amd64 3.3-1build2 [158 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmount-dev amd64 2.37.2-4ubuntu3.4 [14.5 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.3 [1,743 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-dev amd64 2.36.0-3build1 [96.6 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-script-interpreter2 amd64 1.16.0-5ubuntu2 [62.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-dev amd64 0.40.0-1ubuntu0.22.04.1 [280 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render0-dev amd64 1.14-3ubuntu3 [19.6 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shm0-dev amd64 1.14-3ubuntu3 [6,848 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo2-dev amd64 1.16.0-5ubuntu2 [692 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdatrie-dev amd64 0.2.13-2 [19.7 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-dev amd64 1.12.20-2ubuntu4.1 [188 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-bin amd64 1.20.0-1ubuntu0.1 [20.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-dev amd64 1.20.0-1ubuntu0.1 [69.5 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-dev amd64 0.1.0-3build1 [5,544 B]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [11.1 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-dev amd64 1.1.6-1 [54.4 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-mainloop-glib0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [12.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse-dev amd64 1:15.99.1+dfsg1-1ubuntu2.2 [75.6 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [9,546 B]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa-dev amd64 9.0.2-1 [231 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libibus-1.0-dev amd64 1.5.26-4 [185 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio-dev amd64 1.8.1-1.1 [17.8 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libudev-dev amd64 249.11-0ubuntu3.12 [20.7 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes-dev amd64 1:6.0.0-1 [12.2 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor-dev amd64 1:1.2.0-2build4 [28.2 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi-dev amd64 2:1.8-1build1 [193 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama-dev amd64 2:1.1.4-3 [8,104 B]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-dev amd64 1.4.0-1 [54.9 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr-dev amd64 2:1.5.2-1build1 [26.7 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv-dev amd64 2:1.0.11-1build2 [33.4 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm-dev amd64 1:1.1.4-1build3 [13.9 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsdl2-dev amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [1,767 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsystemd-dev amd64 249.11-0ubuntu3.12 [306 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth-dev amd64 2.2.5-1 [35.1 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfribidi-dev amd64 1.0.8-2ubuntu3.1 [64.8 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail18 amd64 2.24.33-2ubuntu2.1 [15.9 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgail-common amd64 2.24.33-2ubuntu2.1 [132 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.42.8+dfsg-1ubuntu0.3 [14.2 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf-2.0-dev amd64 2.42.8+dfsg-1ubuntu0.3 [47.8 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgme-dev amd64 0.6.3-2 [7,884 B]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphite2-dev amd64 1.3.14-1build2 [14.7 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk2.0-bin amd64 2.24.33-2ubuntu2.1 [7,936 B]
# Get:99 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.1 [5,886 B]
# Get:100 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-gobject0 amd64 2.7.4-1ubuntu3.1 [26.0 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-dev amd64 2.7.4-1ubuntu3.1 [553 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai-dev amd64 0.1.29-1build1 [26.4 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pango1.0-tools amd64 1.50.6+ds-2ubuntu1 [45.8 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpango1.0-dev amd64 1.50.6+ds-2ubuntu1 [154 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite-dev amd64 1:0.4.5-1build2 [9,326 B]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdamage-dev amd64 1:1.1.5-2build2 [5,264 B]
# Get:107 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2-utils amd64 2.9.13+dfsg-1ubuntu0.4 [40.2 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgtk2.0-dev amd64 2.24.33-2ubuntu2.1 [778 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsys-hostname-long-perl all 1.5-2 [11.5 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmail-sendmail-perl all 0.80-1.1 [22.7 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal-dev amd64 1:1.19.1-2build3 [22.7 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi-config all 0.4.3-1 [12.4 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi-dev amd64 0.4.3-1 [93.2 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy/universe amd64 nasm amd64 2.15.05-1 [375 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 timidity amd64 2.14.0-8ubuntu1.22.04.1 [681 kB]
# Fetched 176 MB in 3s (64.4 MB/s)
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../tar_1.34+dfsg-1ubuntu0.1.22.04.2_amd64.deb ...
# Unpacking tar (1.34+dfsg-1ubuntu0.1.22.04.2) over (1.34+dfsg-1ubuntu0.1.22.04.1) ...
# Setting up tar (1.34+dfsg-1ubuntu0.1.22.04.2) ...
# update-alternatives: warning: forcing reinstallation of alternative /usr/sbin/rmt-tar because link group rmt is broken
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../libblkid1_2.37.2-4ubuntu3.4_amd64.deb ...
# Unpacking libblkid1:amd64 (2.37.2-4ubuntu3.4) over (2.37.2-4ubuntu3) ...
# Setting up libblkid1:amd64 (2.37.2-4ubuntu3.4) ...
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../libmount1_2.37.2-4ubuntu3.4_amd64.deb ...
# Unpacking libmount1:amd64 (2.37.2-4ubuntu3.4) over (2.37.2-4ubuntu3) ...
# Setting up libmount1:amd64 (2.37.2-4ubuntu3.4) ...
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../libudev1_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev1:amd64 (249.11-0ubuntu3.12) over (249.11-0ubuntu3.10) ...
# Setting up libudev1:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package gettext-base.
# (Reading database ... 123621 files and directories currently installed.)
# Preparing to unpack .../000-gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../001-autopoint_0.21-4ubuntu4_all.deb ...
# Unpacking autopoint (0.21-4ubuntu4) ...
# Selecting previously unselected package libdebhelper-perl.
# Preparing to unpack .../002-libdebhelper-perl_13.6ubuntu1_all.deb ...
# Unpacking libdebhelper-perl (13.6ubuntu1) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../003-libtool_2.4.6-15build2_all.deb ...
# Unpacking libtool (2.4.6-15build2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../004-dh-autoreconf_20_all.deb ...
# Unpacking dh-autoreconf (20) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../005-libarchive-zip-perl_1.68-1_all.deb ...
# Unpacking libarchive-zip-perl (1.68-1) ...
# Selecting previously unselected package libsub-override-perl.
# Preparing to unpack .../006-libsub-override-perl_0.09-2_all.deb ...
# Unpacking libsub-override-perl (0.09-2) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../007-libfile-stripnondeterminism-perl_1.13.0-1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (1.13.0-1) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../008-dh-strip-nondeterminism_1.13.0-1_all.deb ...
# Unpacking dh-strip-nondeterminism (1.13.0-1) ...
# Selecting previously unselected package debugedit.
# Preparing to unpack .../009-debugedit_1%3a5.0-4build1_amd64.deb ...
# Unpacking debugedit (1:5.0-4build1) ...
# Selecting previously unselected package dwz.
# Preparing to unpack .../010-dwz_0.14-1build2_amd64.deb ...
# Unpacking dwz (0.14-1build2) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../011-gettext_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext (0.21-4ubuntu4) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../012-intltool-debian_0.35.0+20060710.5_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.5) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../013-po-debconf_1.0.21+nmu1_all.deb ...
# Unpacking po-debconf (1.0.21+nmu1) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../014-debhelper_13.6ubuntu1_all.deb ...
# Unpacking debhelper (13.6ubuntu1) ...
# Selecting previously unselected package fluid-soundfont-gm.
# Preparing to unpack .../015-fluid-soundfont-gm_3.1-5.3_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.3) ...
# Selecting previously unselected package freepats.
# Preparing to unpack .../016-freepats_20060219-4_all.deb ...
# Unpacking freepats (20060219-4) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../017-gir1.2-atk-1.0_2.36.0-3build1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../018-gir1.2-freedesktop_1.72.0-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../019-gir1.2-gdkpixbuf-2.0_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../020-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package gir1.2-harfbuzz-0.0:amd64.
# Preparing to unpack .../021-gir1.2-harfbuzz-0.0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../022-libpangoxft-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../023-gir1.2-pango-1.0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../024-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package gir1.2-gtk-2.0:amd64.
# Preparing to unpack .../025-gir1.2-gtk-2.0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../026-libibus-1.0-5_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.26-4) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../027-gir1.2-ibus-1.0_1.5.26-4_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Selecting previously unselected package libao-common.
# Preparing to unpack .../028-libao-common_1.2.2+20180113-1.1ubuntu3_all.deb ...
# Unpacking libao-common (1.2.2+20180113-1.1ubuntu3) ...
# Selecting previously unselected package libao4:amd64.
# Preparing to unpack .../029-libao4_1.2.2+20180113-1.1ubuntu3_amd64.deb ...
# Unpacking libao4:amd64 (1.2.2+20180113-1.1ubuntu3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../030-libarchive-cpio-perl_0.10-1.1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1.1) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../031-libffi-dev_3.4.2-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.4.2-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../032-libglib2.0-dev-bin_2.72.4-0ubuntu2.3_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.3) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../033-libblkid-dev_2.37.2-4ubuntu3.4_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.37.2-4ubuntu3.4) ...
# Selecting previously unselected package libsepol-dev:amd64.
# Preparing to unpack .../034-libsepol-dev_3.3-1build1_amd64.deb ...
# Unpacking libsepol-dev:amd64 (3.3-1build1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../035-libselinux1-dev_3.3-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.3-1build2) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../036-libmount-dev_2.37.2-4ubuntu3.4_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.37.2-4ubuntu3.4) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../037-libglib2.0-dev_2.72.4-0ubuntu2.3_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.3) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../038-libatk1.0-dev_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../039-liblzo2-2_2.10-2build3_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2build3) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../040-libcairo-script-interpreter2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../041-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../042-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../043-libpixman-1-dev_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../044-libxcb-render0-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../045-libxcb-shm0-dev_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../046-libcairo2-dev_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libdatrie-dev:amd64.
# Preparing to unpack .../047-libdatrie-dev_0.2.13-2_amd64.deb ...
# Unpacking libdatrie-dev:amd64 (0.2.13-2) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../048-libdbus-1-dev_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../049-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../050-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libdecor-0-dev:amd64.
# Preparing to unpack .../051-libdecor-0-dev_0.1.0-3build1_amd64.deb ...
# Unpacking libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Selecting previously unselected package libpciaccess-dev:amd64.
# Preparing to unpack .../052-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../053-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../054-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../055-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../056-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../057-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../058-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../059-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../060-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../061-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../062-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../063-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../064-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package libinstpatch-dev:amd64.
# Preparing to unpack .../065-libinstpatch-dev_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-dev:amd64 (1.1.6-1) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../066-libpulse-mainloop-glib0_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../067-libpulse-dev_1%3a15.99.1+dfsg1-1ubuntu2.2_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Selecting previously unselected package libgbm-dev:amd64.
# Preparing to unpack .../068-libgbm-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libgbm-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../069-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../070-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../071-libibus-1.0-dev_1.5.26-4_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.26-4) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../072-libsndio-dev_1.8.1-1.1_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.8.1-1.1) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../073-libudev-dev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libudev-dev:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../074-libxfixes-dev_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../075-libxcursor-dev_1%3a1.2.0-2build4_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Selecting previously unselected package libxi-dev:amd64.
# Preparing to unpack .../076-libxi-dev_2%3a1.8-1build1_amd64.deb ...
# Unpacking libxi-dev:amd64 (2:1.8-1build1) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../077-libxinerama-dev_2%3a1.1.4-3_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.4-3) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../078-libxkbcommon-dev_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../079-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../080-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../081-libxv-dev_2%3a1.0.11-1build2_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1build2) ...
# Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../082-libxxf86vm-dev_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../083-libsdl2-dev_2.0.20+dfsg-2ubuntu1.22.04.1_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Selecting previously unselected package libsystemd-dev:amd64.
# Preparing to unpack .../084-libsystemd-dev_249.11-0ubuntu3.12_amd64.deb ...
# Unpacking libsystemd-dev:amd64 (249.11-0ubuntu3.12) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../085-libfluidsynth-dev_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (2.2.5-1) ...
# Selecting previously unselected package libfribidi-dev:amd64.
# Preparing to unpack .../086-libfribidi-dev_1.0.8-2ubuntu3.1_amd64.deb ...
# Unpacking libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../087-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../088-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-bin.
# Preparing to unpack .../089-libgdk-pixbuf2.0-bin_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package libgdk-pixbuf-2.0-dev:amd64.
# Preparing to unpack .../090-libgdk-pixbuf-2.0-dev_2.42.8+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking libgdk-pixbuf-2.0-dev:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package libgme-dev:amd64.
# Preparing to unpack .../091-libgme-dev_0.6.3-2_amd64.deb ...
# Unpacking libgme-dev:amd64 (0.6.3-2) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../092-libgraphite2-dev_1.3.14-1build2_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.14-1build2) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../093-libgtk2.0-bin_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../094-libharfbuzz-icu0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../095-libharfbuzz-gobject0_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../096-libharfbuzz-dev_2.7.4-1ubuntu3.1_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.1) ...
# Selecting previously unselected package libthai-dev:amd64.
# Preparing to unpack .../097-libthai-dev_0.1.29-1build1_amd64.deb ...
# Unpacking libthai-dev:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package pango1.0-tools.
# Preparing to unpack .../098-pango1.0-tools_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpango1.0-dev:amd64.
# Preparing to unpack .../099-libpango1.0-dev_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../100-libxcomposite-dev_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../101-libxdamage-dev_1%3a1.1.5-2build2_amd64.deb ...
# Unpacking libxdamage-dev:amd64 (1:1.1.5-2build2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../102-libxml2-utils_2.9.13+dfsg-1ubuntu0.4_amd64.deb ...
# Unpacking libxml2-utils (2.9.13+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package libgtk2.0-dev:amd64.
# Preparing to unpack .../103-libgtk2.0-dev_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-dev:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../104-libsys-hostname-long-perl_1.5-2_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-2) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../105-libmail-sendmail-perl_0.80-1.1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1.1) ...
# Selecting previously unselected package libopenal-dev:amd64.
# Preparing to unpack .../106-libopenal-dev_1%3a1.19.1-2build3_amd64.deb ...
# Unpacking libopenal-dev:amd64 (1:1.19.1-2build3) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../107-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libwildmidi-config.
# Preparing to unpack .../108-libwildmidi-config_0.4.3-1_all.deb ...
# Unpacking libwildmidi-config (0.4.3-1) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../109-libwildmidi2_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.3-1) ...
# Selecting previously unselected package libwildmidi-dev.
# Preparing to unpack .../110-libwildmidi-dev_0.4.3-1_amd64.deb ...
# Unpacking libwildmidi-dev (0.4.3-1) ...
# Selecting previously unselected package nasm.
# Preparing to unpack .../111-nasm_2.15.05-1_amd64.deb ...
# Unpacking nasm (2.15.05-1) ...
# Selecting previously unselected package timidity.
# Preparing to unpack .../112-timidity_2.14.0-8ubuntu1.22.04.1_amd64.deb ...
# Unpacking timidity (2.14.0-8ubuntu1.22.04.1) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.3) ...
# Setting up libblkid-dev:amd64 (2.37.2-4ubuntu3.4) ...
# Setting up freepats (20060219-4) ...
# Setting up gir1.2-freedesktop:amd64 (1.72.0-1) ...
# Setting up libsndio-dev:amd64 (1.8.1-1.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libpixman-1-dev:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up libpangoxft-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libtool (2.4.6-15build2) ...
# Setting up gir1.2-atk-1.0:amd64 (2.36.0-3build1) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libarchive-zip-perl (1.68-1) ...
# Setting up libopenal-dev:amd64 (1:1.19.1-2build3) ...
# Setting up libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up libxxf86vm-dev:amd64 (1:1.1.4-1build3) ...
# Setting up libxkbcommon-dev:amd64 (1.4.0-1) ...
# Setting up libdebhelper-perl (13.6ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.26-4) ...
# Setting up pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Setting up libgme-dev:amd64 (0.6.3-2) ...
# Setting up gettext-base (0.21-4ubuntu4) ...
# Setting up liblzo2-2:amd64 (2.10-2build3) ...
# Setting up libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libffi-dev:amd64 (3.4.2-4) ...
# Setting up gir1.2-harfbuzz-0.0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libgbm-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libao-common (1.2.2+20180113-1.1ubuntu3) ...
# Setting up libxfixes-dev:amd64 (1:6.0.0-1) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-3ubuntu3) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1build2) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up libgraphite2-dev:amd64 (1.3.14-1build2) ...
# Setting up gir1.2-pango-1.0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up libwildmidi-config (0.4.3-1) ...
# Setting up libdbus-1-dev:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up autopoint (0.21-4ubuntu4) ...
# Setting up libudev-dev:amd64 (249.11-0ubuntu3.12) ...
# Setting up libxinerama-dev:amd64 (2:1.1.4-3) ...
# Setting up libsepol-dev:amd64 (3.3-1build1) ...
# Setting up libxcb-render0-dev:amd64 (1.14-3ubuntu3) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up nasm (2.15.05-1) ...
# Setting up libao4:amd64 (1.2.2+20180113-1.1ubuntu3) ...
# Setting up dwz (0.14-1build2) ...
# Setting up libdatrie-dev:amd64 (0.2.13-2) ...
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libarchive-cpio-perl (0.10-1.1) ...
# Setting up debugedit (1:5.0-4build1) ...
# Setting up libsub-override-perl (0.09-2) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up fluid-soundfont-gm (3.1-5.3) ...
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libxi-dev:amd64 (2:1.8-1build1) ...
# Setting up libxml2-utils (2.9.13+dfsg-1ubuntu0.4) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.26-4) ...
# Setting up libsys-hostname-long-perl (1.5-2) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libsystemd-dev:amd64 (249.11-0ubuntu3.12) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libxdamage-dev:amd64 (1:1.1.5-2build2) ...
# Setting up libfile-stripnondeterminism-perl (1.13.0-1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up gettext (0.21-4ubuntu4) ...
# Setting up timidity (2.14.0-8ubuntu1.22.04.1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libselinux1-dev:amd64 (3.3-1build2) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.5-1build2) ...
# Setting up libxcursor-dev:amd64 (1:1.2.0-2build4) ...
# Setting up libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libwildmidi-dev (0.4.3-1) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up intltool-debian (0.35.0+20060710.5) ...
# Setting up libdecor-0-dev:amd64 (0.1.0-3build1) ...
# Setting up dh-autoreconf (20) ...
# Setting up libmail-sendmail-perl (0.80-1.1) ...
# Setting up gir1.2-gtk-2.0:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libthai-dev:amd64 (0.1.29-1build1) ...
# Setting up dh-strip-nondeterminism (1.13.0-1) ...
# Setting up libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up libgtk2.0-bin (2.24.33-2ubuntu2.1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libmount-dev:amd64 (2.37.2-4ubuntu3.4) ...
# Setting up libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Setting up po-debconf (1.0.21+nmu1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up debhelper (13.6ubuntu1) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.3) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Setting up libibus-1.0-dev:amd64 (1.5.26-4) ...
# Setting up libpulse-dev:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libcairo2-dev:amd64 (1.16.0-5ubuntu2) ...
# Setting up libinstpatch-dev:amd64 (1.1.6-1) ...
# Setting up libatk1.0-dev:amd64 (2.36.0-3build1) ...
# Setting up libgdk-pixbuf-2.0-dev:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libsdl2-dev:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up libfluidsynth-dev:amd64 (2.2.5-1) ...
# Setting up libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libgtk2.0-dev:amd64 (2.24.33-2ubuntu2.1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libboost-all-dev is already the newest version (1.74.0.3ubuntu7).
# 0 upgraded, 0 newly installed, 0 to remove and 47 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   liblua5.1-0 libtool-bin
# The following NEW packages will be installed:
#   liblua5.1-0 liblua5.1-0-dev libtool-bin
# 0 upgraded, 3 newly installed, 0 to remove and 47 not upgraded.
# Need to get 303 kB of archives.
# After this operation, 1,632 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblua5.1-0 amd64 5.1.5-8.1build4 [99.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblua5.1-0-dev amd64 5.1.5-8.1build4 [122 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtool-bin amd64 2.4.6-15build2 [81.5 kB]
# Fetched 303 kB in 1s (456 kB/s)
# Selecting previously unselected package liblua5.1-0:amd64.
# (Reading database ... 128381 files and directories currently installed.)
# Preparing to unpack .../liblua5.1-0_5.1.5-8.1build4_amd64.deb ...
# Unpacking liblua5.1-0:amd64 (5.1.5-8.1build4) ...
# Selecting previously unselected package liblua5.1-0-dev:amd64.
# Preparing to unpack .../liblua5.1-0-dev_5.1.5-8.1build4_amd64.deb ...
# Unpacking liblua5.1-0-dev:amd64 (5.1.5-8.1build4) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../libtool-bin_2.4.6-15build2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-15build2) ...
# Setting up libtool-bin (2.4.6-15build2) ...
# Setting up liblua5.1-0:amd64 (5.1.5-8.1build4) ...
# Setting up liblua5.1-0-dev:amd64 (5.1.5-8.1build4) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !pip install vizdoom
# !pip install stable_baselines3
# !pip install gym
# !pip install gymnasium
# !git clone https://github.com/mwydmuch/ViZDoom
# !pip install matplotlib
# !pip install stable-baselines3[extra]
# Out:
# Collecting vizdoom
#   Downloading vizdoom-1.2.4-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from vizdoom) (1.26.4)
# Collecting gymnasium>=0.28.0 (from vizdoom)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.10/dist-packages (from vizdoom) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->vizdoom) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium>=0.28.0->vizdoom)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading vizdoom-1.2.4-cp310-cp310-manylinux_2_28_x86_64.whl (28.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.1/28.1 MB 11.4 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 58.0 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium, vizdoom
# Successfully installed farama-notifications-0.0.4 gymnasium-1.0.0 vizdoom-1.2.4
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.3.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting gymnasium<0.30,>=0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.4.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable_baselines3) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Downloading stable_baselines3-2.3.2-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 10.1 MB/s eta 0:00:00
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 47.0 MB/s eta 0:00:00
# Installing collected packages: gymnasium, stable_baselines3
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0
#     Uninstalling gymnasium-1.0.0:
#       Successfully uninstalled gymnasium-1.0.0
# Successfully installed gymnasium-0.29.1 stable_baselines3-2.3.2
# Requirement already satisfied: gym in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Cloning into 'ViZDoom'...
# remote: Enumerating objects: 18734, done.
# remote: Counting objects: 100% (3334/3334), done.
# remote: Compressing objects: 100% (1118/1118), done.
# remote: Total 18734 (delta 2011), reused 3094 (delta 1857), pack-reused 15400 (from 1)
# Receiving objects: 100% (18734/18734), 59.59 MiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (11802/11802), done.
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.3.2)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.4.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.9.2)
# Collecting shimmy~=1.3.0 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (10.4.0)
# Collecting autorom~=0.6.1 (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.3)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 16.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.4.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 66.0 MB/s eta 0:00:00
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446661 sha256=74db5ad177ec69d111c2bf2a9e01b303ff91cd1a3669108adea5af6c6d335870
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: ale-py, shimmy, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 shimmy-1.3.0

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment
import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

from gym import Env
# Import gym spaces
from gym.spaces import Discrete, Box
# Import opencv
import cv2

# %% [markdown]
# # *Gymnasium*

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env):
    # Function that is called when we start the env
    def __init__(self, render=False):
        # Inherit from Env
        super().__init__()
        # Setup the game
        self.game = DoomGame()
        self.game.load_config("ViZDoom/scenarios/basic.cfg")
        #self.set_window_visible(False)
        self.game.set_doom_scenario_path("ViZDoom/scenarios/basic.wad")

        # Render frame logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # Start the game
        self.game.init()

        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)
        self.action_space = Discrete(3)

    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4)

        # Get all the other stuff we need to retun
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0

        info = {"info":info}
        done = self.game.is_episode_finished()

        return state, reward, done, info

    # Define how to render the game or environment
    def render():
        pass

    # What happens when we start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

    # Grayscale the game frame and resize it
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state

    # Call to close down the game
    def close(self):
        self.game.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Import Environment checker
from stable_baselines3.common import env_checker
from matplotlib import pyplot as plt

env = VizDoomGym(render=False)
state = env.reset()

plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Callback

# %%
# Import os for file nav
import os
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# **Train model**

# %%
# import ppo for training
from stable_baselines3 import PPO

# %%
# Non rendered environment
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic/PPO_1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.8     |
# |    ep_rew_mean     | -100     |
# | time/              |          |
# |    fps             | 87       |
# |    iterations      | 1        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40           |
# |    ep_rew_mean          | -123         |
# | time/                   |              |
# |    fps                  | 112          |
# |    iterations           | 2            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0035576755 |
# |    clip_fraction        | 0.17         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -8.75e-05    |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.00218      |
# |    value_loss           | 2.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | -148        |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 3           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009470172 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00769    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 2.7e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 4           |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011249306 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.06e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -9.1e-05    |
# |    value_loss           | 2.45e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 5           |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005206287 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00364    |
# |    value_loss           | 3.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.9        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 6           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014465727 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.45e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 3.08e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.4         |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 7            |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0057900613 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.881       |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.6e+03      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 0.00242      |
# |    value_loss           | 2.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.8        |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 8           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009026412 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.6        |
# |    ep_rew_mean          | -127        |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 9           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.013285385 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.869      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.73e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 3.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.8        |
# |    ep_rew_mean          | -81.8       |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 10          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009724711 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.811      |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.96e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.2        |
# |    ep_rew_mean          | -94.9       |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 11          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017032051 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 913         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.0157      |
# |    value_loss           | 2.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.8        |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 12          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022307893 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.706      |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.47e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00393     |
# |    value_loss           | 2.45e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.2       |
# |    ep_rew_mean          | -52.4      |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 13         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00549442 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.646     |
# |    explained_variance   | 0.674      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.02e+03   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.00441    |
# |    value_loss           | 2.35e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.3        |
# |    ep_rew_mean          | -2.62       |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 14          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.020699052 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00555     |
# |    value_loss           | 3.76e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.5        |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 15          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021137344 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.19e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00448    |
# |    value_loss           | 2.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 51          |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 16          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.038693205 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 678         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 1.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.18        |
# |    ep_rew_mean          | 60.8        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 17          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.048216917 |
# |    clip_fraction        | 0.38        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.751      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 481         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.72        |
# |    ep_rew_mean          | 68.5        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 18          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.040299185 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 129         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 498         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.76        |
# |    ep_rew_mean          | 68.5        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 19          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.050360434 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.384       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 119         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00987     |
# |    value_loss           | 240         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5         |
# |    ep_rew_mean          | 74.8        |
# | time/                   |             |
# |    fps                  | 171         |
# |    iterations           | 20          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021323316 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 182         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.0124      |
# |    value_loss           | 308         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.37        |
# |    ep_rew_mean          | 75.5        |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 21          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.031032974 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.381      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 90.7        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00772     |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.49        |
# |    ep_rew_mean          | 75.9        |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 22          |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.031328645 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.285      |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 94          |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 151         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.13       |
# |    ep_rew_mean          | 78         |
# | time/                   |            |
# |    fps                  | 172        |
# |    iterations           | 23         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03619406 |
# |    clip_fraction        | 0.145      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.278     |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 28.8       |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00899    |
# |    value_loss           | 90.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.09        |
# |    ep_rew_mean          | 77.9        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 24          |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015275706 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.299      |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 52.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0203      |
# |    value_loss           | 87.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.49       |
# |    ep_rew_mean          | 76.3       |
# | time/                   |            |
# |    fps                  | 173        |
# |    iterations           | 25         |
# |    time_elapsed         | 295        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04413424 |
# |    clip_fraction        | 0.184      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.306     |
# |    explained_variance   | 0.454      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 18         |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0415     |
# |    value_loss           | 117        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.1         |
# |    ep_rew_mean          | 77.6        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 26          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.035664767 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 69.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0044      |
# |    value_loss           | 93.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28       |
# |    ep_rew_mean          | 77         |
# | time/                   |            |
# |    fps                  | 173        |
# |    iterations           | 27         |
# |    time_elapsed         | 319        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01893367 |
# |    clip_fraction        | 0.0868     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.239     |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 84.9       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.00863    |
# |    value_loss           | 133        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.4         |
# |    ep_rew_mean          | 77          |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 28          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023308795 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 96.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00317     |
# |    value_loss           | 212         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.97        |
# |    ep_rew_mean          | 78.4        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 29          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.037223764 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 53.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0169      |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 79.2        |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 30          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.017212082 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 41.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.0179      |
# |    value_loss           | 71.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.24        |
# |    ep_rew_mean          | 77.1        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 31          |
# |    time_elapsed         | 364         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.024620036 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.201      |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 20.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 42.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.11       |
# |    ep_rew_mean          | 77.9       |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 32         |
# |    time_elapsed         | 376        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.03741529 |
# |    clip_fraction        | 0.117      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.162     |
# |    explained_variance   | 0.666      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 45.7       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.00213    |
# |    value_loss           | 64.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.29       |
# |    ep_rew_mean          | 77.3       |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 33         |
# |    time_elapsed         | 387        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03354737 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.188     |
# |    explained_variance   | 0.621      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 27.2       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.0329     |
# |    value_loss           | 61.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28        |
# |    ep_rew_mean          | 77.3        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 34          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.054869823 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 29.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0145      |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.34        |
# |    ep_rew_mean          | 77.2        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 35          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017214516 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.24        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.057       |
# |    value_loss           | 42.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.45        |
# |    ep_rew_mean          | 76.4        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 36          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.015639521 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.15       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 50.7        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 48.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.66        |
# |    ep_rew_mean          | 80.2        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 37          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.025117217 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.143      |
# |    explained_variance   | 0.579       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 30.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00617     |
# |    value_loss           | 82.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.18        |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 38          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.031501256 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.133      |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.7        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0444      |
# |    value_loss           | 17.7        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.62      |
# |    ep_rew_mean          | 80        |
# | time/                   |           |
# |    fps                  | 174       |
# |    iterations           | 39        |
# |    time_elapsed         | 456       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.1226152 |
# |    clip_fraction        | 0.139     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.111    |
# |    explained_variance   | 0.476     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 53.1      |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.00242   |
# |    value_loss           | 107       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.79        |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 40          |
# |    time_elapsed         | 467         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.022457406 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.9        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 24.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.06        |
# |    ep_rew_mean          | 77.8        |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 41          |
# |    time_elapsed         | 479         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.037733223 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.115      |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.3        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00195     |
# |    value_loss           | 52.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.91        |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 42          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.023579203 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0995     |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 30.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.99       |
# |    ep_rew_mean          | 78.9       |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 43         |
# |    time_elapsed         | 503        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.07842179 |
# |    clip_fraction        | 0.0813     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.105     |
# |    explained_variance   | 0.793      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 50.4       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 44         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.88        |
# |    ep_rew_mean          | 79.2        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 44          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.045335703 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.12       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.8        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 6.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.29        |
# |    ep_rew_mean          | 77.4        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 45          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.024050847 |
# |    clip_fraction        | 0.0973      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0958     |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.5        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00366     |
# |    value_loss           | 38.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.15        |
# |    ep_rew_mean          | 78.2        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 46          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.016234774 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0987     |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.6        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0193      |
# |    value_loss           | 39.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04        |
# |    ep_rew_mean          | 77.5        |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 47          |
# |    time_elapsed         | 550         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.013629884 |
# |    clip_fraction        | 0.0581      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0919     |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.68        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0213      |
# |    value_loss           | 5.34        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.35       |
# |    ep_rew_mean          | 81.2       |
# | time/                   |            |
# |    fps                  | 175        |
# |    iterations           | 48         |
# |    time_elapsed         | 561        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.07491046 |
# |    clip_fraction        | 0.0945     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0763    |
# |    explained_variance   | 0.624      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 15.1       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.0105     |
# |    value_loss           | 69.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.66        |
# |    ep_rew_mean          | 80          |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 49          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.021051705 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0861     |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.4        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0469      |
# |    value_loss           | 25.2        |
# -----------------------------------------

# %% [markdown]
# https://stackoverflow.com/questions/77766048/getting-a-very-simple-stablebaselines3-example-to-work
